# %%
# %pip install aiogram

# %%
# %pip install psutil aiohttp # 1) m1  RAM 2) курс ЦБ $/руб - НЕ КАНАЕТ

# %%
# %pip install yfinance # instead aiohttp

# %%
# %pip install python-dotenv # get token from file
